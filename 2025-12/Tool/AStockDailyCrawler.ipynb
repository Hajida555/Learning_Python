# %%
import pandas as pd

# %%
import os

# %%
import baostock as bs

# %% [markdown]
# 固定保存路径

# %%
A_share_Raw_Data = "D://python/.ipynb_checkpoints/yuan"

# %%
os.makedirs(A_share_Raw_Data, exist_ok=True)

# %%
stock_list = [
    "sh.600519",
    "sz.000001",
    "
